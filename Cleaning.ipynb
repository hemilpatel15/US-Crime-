# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/hemilpatel/Desktop/Crime Data 2020-2024.csv')
# Out:
# /var/folders/k7/l986pfx93rl8446kk42hp2n40000gn/T/ipykernel_21758/2792812630.py:1: DtypeWarning: Columns (1,2,5,9,10,12,13,15,17,18,19,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/hemilpatel/Desktop/Crime Data 2020-2024.csv')

# %%
df
# Out:
#                DR_NO      Date Rptd      DATE OCC  TIME OCC  AREA   AREA NAME  \
# 0        190326475.0    3/1/20 0:00   3/1/20 0:00    2130.0   7.0    Wilshire
# 1        200106753.0    2/9/20 0:00   2/8/20 0:00    1800.0   1.0     Central
# 2        200320258.0  11/11/20 0:00  11/4/20 0:00    1700.0   3.0   Southwest
# 3        200907217.0   5/10/23 0:00  3/10/20 0:00    2037.0   9.0    Van Nuys
# 4        200412582.0    9/9/20 0:00   9/9/20 0:00     630.0   4.0  Hollenbeck
# ...              ...            ...           ...       ...   ...         ...
# 1005104          NaN            NaN           NaN       NaN   NaN         NaN
# 1005105          NaN            NaN           NaN       NaN   NaN         NaN
# 1005106          NaN            NaN           NaN       NaN   NaN         NaN
# 1005107          NaN            NaN           NaN       NaN   NaN         NaN
# 1005108          NaN            NaN           NaN       NaN   NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005109 entries, 0 to 1005108
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           100000 non-null  float64
#  1   Date Rptd       100000 non-null  object
#  2   DATE OCC        100000 non-null  object
#  3   TIME OCC        100000 non-null  float64
#  4   AREA            100000 non-null  float64
#  5   AREA NAME       100000 non-null  object
#  6   Rpt Dist No     100000 non-null  float64
#  7   Part 1-2        100000 non-null  float64
#  8   Crm Cd          100000 non-null  float64
#  9   Crm Cd Desc     100000 non-null  object
#  10  Mocodes         87406 non-null   object
#  11  Vict Age        100000 non-null  float64
#  12  Vict Sex        87837 non-null   object
#  13  Vict Descent    87834 non-null   object
#  14  Premis Cd       99999 non-null   float64
#  15  Premis Desc     99962 non-null   object
# ...

# %%
df_cleaned = df.drop(columns=[
    'Rpt Dist No', 'Part 1-2', 'Mocodes', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4',
    'Weapon Used Cd', 'Cross Street'
])

# %%
df_cleaned
# Out:
#                DR_NO      Date Rptd      DATE OCC  TIME OCC  AREA   AREA NAME  \
# 0        190326475.0    3/1/20 0:00   3/1/20 0:00    2130.0   7.0    Wilshire
# 1        200106753.0    2/9/20 0:00   2/8/20 0:00    1800.0   1.0     Central
# 2        200320258.0  11/11/20 0:00  11/4/20 0:00    1700.0   3.0   Southwest
# 3        200907217.0   5/10/23 0:00  3/10/20 0:00    2037.0   9.0    Van Nuys
# 4        200412582.0    9/9/20 0:00   9/9/20 0:00     630.0   4.0  Hollenbeck
# ...              ...            ...           ...       ...   ...         ...
# 1005104          NaN            NaN           NaN       NaN   NaN         NaN
# 1005105          NaN            NaN           NaN       NaN   NaN         NaN
# 1005106          NaN            NaN           NaN       NaN   NaN         NaN
# 1005107          NaN            NaN           NaN       NaN   NaN         NaN
# 1005108          NaN            NaN           NaN       NaN   NaN         NaN
#
# ...

# %%
df_cleaned
# Out:
#              DR_NO      Date Rptd      DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0      190326475.0    3/1/20 0:00   3/1/20 0:00    2130.0   7.0     Wilshire
# 1      200106753.0    2/9/20 0:00   2/8/20 0:00    1800.0   1.0      Central
# 2      200320258.0  11/11/20 0:00  11/4/20 0:00    1700.0   3.0    Southwest
# 3      200907217.0   5/10/23 0:00  3/10/20 0:00    2037.0   9.0     Van Nuys
# 4      200412582.0    9/9/20 0:00   9/9/20 0:00     630.0   4.0   Hollenbeck
# ...            ...            ...           ...       ...   ...          ...
# 99995  201009644.0   5/30/20 0:00  4/20/20 0:00    1220.0  10.0  West Valley
# 99996  200604088.0    1/1/20 0:00   1/1/20 0:00    1210.0   6.0    Hollywood
# 99997  200214668.0    9/4/20 0:00   9/4/20 0:00     100.0   2.0      Rampart
# 99998  201210009.0   3/30/20 0:00  3/29/20 0:00     100.0  12.0  77th Street
# 99999  201211636.0   4/11/20 0:00   4/9/20 0:00     950.0  12.0  77th Street
#
# ...

# %%
df1 = df_cleaned

# %%
df1
# Out:
#              DR_NO      Date Rptd      DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0      190326475.0    3/1/20 0:00   3/1/20 0:00    2130.0   7.0     Wilshire
# 1      200106753.0    2/9/20 0:00   2/8/20 0:00    1800.0   1.0      Central
# 2      200320258.0  11/11/20 0:00  11/4/20 0:00    1700.0   3.0    Southwest
# 3      200907217.0   5/10/23 0:00  3/10/20 0:00    2037.0   9.0     Van Nuys
# 4      200412582.0    9/9/20 0:00   9/9/20 0:00     630.0   4.0   Hollenbeck
# ...            ...            ...           ...       ...   ...          ...
# 99995  201009644.0   5/30/20 0:00  4/20/20 0:00    1220.0  10.0  West Valley
# 99996  200604088.0    1/1/20 0:00   1/1/20 0:00    1210.0   6.0    Hollywood
# 99997  200214668.0    9/4/20 0:00   9/4/20 0:00     100.0   2.0      Rampart
# 99998  201210009.0   3/30/20 0:00  3/29/20 0:00     100.0  12.0  77th Street
# 99999  201211636.0   4/11/20 0:00   4/9/20 0:00     950.0  12.0  77th Street
#
# ...

# %%
df1.to_excel("cleaned_data.xlsx", index=False)
